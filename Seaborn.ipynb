# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
pwd
# Out:
# 'C:\\Users\\pravi'

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
tips['tip']
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
tips['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
# distribution plot (dust plot)

# %%
sns.distplot(tips['total_bill'])

# %%
tips['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
sns.distplot(tips['total_bill'],bins=10,kde=True)  #bins:vertical lines  with KDE

# %%
sns.distplot(tips['total_bill'],bins=10,kde=False)  #bins:vertical lines  without KDE

# %%
sns.distplot(tips['total_bill'],bins=20,kde=True)  #bins:vertical lines  with KDE

# %%
sns.distplot(tips['total_bill'],bins=10,kde=True,hist=)

# %%
# scatter plot

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='scatter')

# %%
# Hexagon plot

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='resid')

# %%
# pair plot

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='smoker')

# %%
sns.pairplot(tips,hue='sex',palette='husl')

# %%
#rugplot

# %%
sns.rugplot(tips['total_bill'])

# %%
sns.kdeplot(tips['tip'])

# %%
# categorical graph 1. factor plot 2.box plot 3. violin plot 4. strip plot 5.swarm plot 6. bar plot 7. count plot

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# # bar plot and count plot

# %%
sns.barplot(x='sex',y='total_bill',data=tips)

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
sns.barplot(x='sex',y='tip',data=tips)

# %%
#sns.set(style='whitegrid')  # background grid
sns.barplot(x='sex',y='tip',data=tips)

# %%
import numpy as np

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=sum)

# %%
sns.barplot(x='sex',y='total_bill',data=tips)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-30752f89368e> in <module>
# ----> 1 sns.barplot(x='sex',y='total_bill',data=tips)
#
# NameError: name 'sns' is not defined

# %%
# count plot

# %%
sns.countplot(x='time',data=tips)

# %%
sns.countplot(x='sex',data=tips)

# %%
sns.countplot(x='smoker',data=tips)

# %%
tips.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
sns.countplot(x='size',data=tips)

# %%
#boxplot

# %%
sns.boxplot(x='day',y='total_bill',data=tips)

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.boxplot(x='size',y='tip',data=tips)

# %%
sns.boxplot(data=tips,palette='rainbow')   # only of numerical column  vertical method

# %%
sns.boxplot(data=tips,palette='rainbow',orient='h')   # horizontal method

# %%
sns.boxplot(x='day',y='total_bill',hue='smoker',data=tips,palette='coolwarm')

# %%
#violin plot

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='smoker')

# %%
# strip plot

# %%
sns.stripplot(x='day',y='total_bill',data=tips)

# %%
# swarm plot

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)

# %%
sns.violinplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips,color='black')

# %%
sns.swarmplot(x='day',y='total_bill',data=tips,hue='sex',dodge=True)

# %%
# factor plot

# %%
sns.factorplot(x='sex',y='total_bill',data=tips,kind='bar')

# %%
sns.catplot(x='sex',y='total_bill',data=tips,kind='point')

# %%
# matrix plot

# %%
a=sns.load_dataset('flights')

# %%
a.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
# heatmap   : method to show matrix data

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())

# %%
sns.heatmap(tips.corr(),cmap='coolwarm',annot=True)

# %%
# %matplotlib inline

# %%
sns.heatmap(tips.corr(),cmap='Set1',annot=True)

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips =sns.load_dataset('tips')

# %%
flights=sns.load_dataset('flights')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
# pivot concept

# %%
flights.pivot_table(values='passengers',index='month',columns='year')
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
flights.pivot_table(values='passengers',index='year',columns='month')
# Out:
# month  January  February  March  April  May  June  July  August  September  \
# year
# 1949       112       118    132    129  121   135   148     148        136
# 1950       115       126    141    135  125   149   170     170        158
# 1951       145       150    178    163  172   178   199     199        184
# 1952       171       180    193    181  183   218   230     242        209
# 1953       196       196    236    235  229   243   264     272        237
# 1954       204       188    235    227  234   264   302     293        259
# 1955       242       233    267    269  270   315   364     347        312
# 1956       284       277    317    313  318   374   413     405        355
# 1957       315       301    356    348  355   422   465     467        404
# 1958       340       318    362    348  363   435   491     505        404
# 1959       360       342    406    396  420   472   548     559        463
# ...

# %%
a=flights.pivot_table(values='passengers',index='month',columns='year')
sns.heatmap(a)

# %%
sns.heatmap(a,cmap='YlGnBu')

# %%
# cluster map

# %%
sns.clustermap(a,cmap='YlGnBu')

# %%
# Grids plot

# %%
b=sns.load_dataset('iris')
print(b)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
b.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
b.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import matplotlib.pyplot as plt
sns.PairGrid(b)
b.map(plt.scatter)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-456a0731a818> in <module>
#       1 import matplotlib.pyplot as plt
#       2 sns.PairGrid(b)
# ----> 3 b.map(plt.scatter)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'map'

# %%
import matplotlib.pyplot as plt

# %%
z=sns.PairGrid(b)
z.map(plt.scatter)
z.map_diag(plt.hist)
z.map_diag(sns.distplot)

# %%
sns.pairplot(b,palette='coolwarm',hue='species')

# %%
# face grid

# %%
sns.FaceGrid(tips,col='time',row='smoker')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-700fef9610b9> in <module>
# ----> 1 sns.FaceGrid(tips,col='time',row='smoker')
#
# AttributeError: module 'seaborn' has no attribute 'FaceGrid'

# %%
z=tips =sns.load_dataset('tips')

# %%
z=sns.FacetGrid(tips,col='time',row='smoker')

# %%
z=sns.FacetGrid(tips,col='time',row='smoker',hue='sex')
z=z.map(plt.hist,'total_bill')

# %%
z=sns.FacetGrid(tips,col='time',row='smoker',hue='sex')
z=z.map(plt.hist,'total_bill').add_legend()

# %%
z=sns.FacetGrid(tips,col='time',row='smoker',hue='sex')
z=z.map(plt.scatter,'total_bill','tip').add_legend()

# %%
g=sns.JointGrid(x='total_bill',y='tip',data=tips)
g=g.plot(sns.regplot,sns.distplot)

# %%
# regression plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='rainbow',markers=['o','x'],scatter_kws={'s':500})

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='smoker',row='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',palette='Set1')
